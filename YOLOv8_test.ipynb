# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('/Users/sachinkarthikeya/Desktop/Projects/NPD-YOLO/best.pt')

sample_image_path = '/Users/sachinkarthikeya/Desktop/Projects/NPD-YOLO/test_plate.jpg'

# %%
for i, box in enumerate(results[0].boxes.xyxy):  
    x1, y1, x2, y2 = map(int, box)  
    conf = results[0].boxes.conf[i]  
    label = f"Confidence: {conf:.2f}"

    cv2.rectangle(original_image, (x1, y1), (x2, y2), (255, 0, 0), 2)  

    cv2.putText(original_image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

plt.figure(figsize=(10, 10))
plt.imshow(original_image)
plt.axis("off")
plt.title("Detection Result with Bounding Boxes")
plt.show()
